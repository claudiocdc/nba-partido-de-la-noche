# %% [markdown]
# # KPI del partido de la noche — NBA
# Para una fecha dada, calcula qué partido de la NBA fue el más interesante de ver (nota 0–100), combinando igualdad del marcador, prórrogas, ritmo anotador y mejor actuación individual (Game Score de Hollinger).
#
# ## 1. Instalación y descarga de datos
# Instalamos `nba_api` y bajamos los partidos de la fecha desde la API oficial de la NBA.

# %%
# !pip install nba_api
# Out:
# Requirement already satisfied: nba_api in .\anaconda3\Lib\site-packages (1.11.4)
# Requirement already satisfied: numpy>=2.1.0 in .\anaconda3\Lib\site-packages (from nba_api) (2.4.6)
# Requirement already satisfied: pandas>=2.2.0 in .\anaconda3\Lib\site-packages (from nba_api) (3.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in .\anaconda3\Lib\site-packages (from nba_api) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2026.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\anaconda3\Lib\site-packages (from pandas>=2.2.0->nba_api) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\anaconda3\Lib\site-packages (from pandas>=2.2.0->nba_api) (2026.2)
# Requirement already satisfied: six>=1.5 in .\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nba_api) (1.17.0)

# %%
from datetime import date, timedelta

# --- Fecha a analizar ---
# Para la temporada (automático, ayer):
fecha = (date.today() - timedelta(days=1)).strftime("%Y-%m-%d")

# Para probar ahora (una fecha con partidos):
fecha = "2026-04-10"

print("Analizando los partidos del:", fecha)
# Out:
# Analizando los partidos del: 2026-04-10

# %%
from nba_api.stats.endpoints import scoreboardv3

sb = scoreboardv3.ScoreboardV3(game_date=fecha, timeout=120)
dfs = sb.get_data_frames()
print("tablas:", len(dfs))
for i, d in enumerate(dfs):
    print(i, d.shape, list(d.columns))
# Out:
# tablas: 6
# 0 (1, 3) ['gameDate', 'leagueId', 'leagueName']
# 1 (15, 18) ['gameId', 'gameCode', 'gameStatus', 'gameStatusText', 'period', 'gameClock', 'gameTimeUTC', 'gameEt', 'regulationPeriods', 'seriesGameNumber', 'gameLabel', 'gameSubLabel', 'seriesText', 'ifNecessary', 'seriesConference', 'poRoundDesc', 'gameSubtype', 'isNeutral']
# 2 (30, 12) ['gameId', 'teamId', 'teamCity', 'teamName', 'teamTricode', 'teamSlug', 'wins', 'losses', 'score', 'seed', 'inBonus', 'timeoutsRemaining']
# 3 (30, 12) ['gameId', 'teamId', 'leaderType', 'personId', 'name', 'playerSlug', 'jerseyNum', 'position', 'teamTricode', 'points', 'rebounds', 'assists']
# 4 (30, 13) ['gameId', 'teamId', 'leaderType', 'personId', 'name', 'playerSlug', 'jerseyNum', 'position', 'teamTricode', 'points', 'rebounds', 'assists', 'seasonLeadersFlag']
# 5 (75, 6) ['gameId', 'broadcasterType', 'broadcasterId', 'broadcastDisplay', 'broadcasterTeamId', 'broadcasterDescription']

# %% [markdown]
# ## 2. Motor del KPI
# Las funciones que convierten cada métrica en nota (0–1) y los pesos.

# %%
"""
KPI v1 "Partido del dia" - motor de puntuacion (solo box score).
Escala 0-100. Cada componente se normaliza a 0-1 y se pondera.
Los PESOS son una hipotesis: se calibran mirando noches reales.
"""

def _clip01(x):
    return max(0.0, min(1.0, x))

# ---- Componentes (cada uno devuelve 0..1) ----

def closeness_score(final_margin):
    """Igualdad del resultado. Margen 0 -> 1.0 ; margen >=20 -> 0."""
    return _clip01(1 - final_margin / 20.0)

def overtime_score(num_ot):
    """Prorrogas. 0 -> 0 ; 1 -> 0.7 ; 2+ -> 1.0."""
    if num_ot <= 0:
        return 0.0 
    return _clip01(0.7 + 0.3 * (num_ot - 1))

def pace_score(total_points):
    """Ritmo anotador. 200 pts totales -> 0 ; 260 -> 1 (rango tipico NBA)."""
    return _clip01((total_points - 200) / 60.0)

def star_score(best_game_score):
    """Mejor actuacion individual (game score de Hollinger). 15 -> 0 ; 45 -> 1."""
    return _clip01((best_game_score - 15) / 30.0)

# ---- Pesos v1 (suman 1.0) ----
WEIGHTS = {"closeness": 0.45, "overtime": 0.20, "pace": 0.05, "star": 0.30}

# %% [markdown]
# ## 3. Marcador de cada partido
# Sacamos margen final y puntos totales de cada partido.

# %%
line = dfs[2]

# Agrupamos por partido y, sobre el marcador de cada grupo, sacamos varias cosas
resumen = line.groupby("gameId")["score"].agg(
    total="sum",
    maximo="max",
    minimo="min"
)
resumen["margen"] = resumen["maximo"] - resumen["minimo"]
if len(resumen) == 0:
    print("No hubo partidos el", fecha)

print(resumen.head())
# Out:
#             total  maximo  minimo  margen
# gameId
# 0022501171    218     118     100      18
# 0022501172    257     140     117      23
# 0022501173    226     124     102      22
# 0022501174    262     144     118      26
# 0022501175    199     105      94      11

# %% [markdown]
# ## 4. Prórrogas
# Contamos las prórrogas de cada partido y las añadimos a `resumen`.

# %%
# Recuperamos la cabecera del 10 de abril y sacamos las prorrogas de la columna correcta
header = dfs[1].copy()
header["prorrogas"] = header["period"] - 4

# Lo unimos a nuestro 'resumen' (que tenia total y margen) por el gameId
resumen = resumen.join(header.set_index("gameId")["prorrogas"])

print(resumen[["margen", "total", "prorrogas"]])
# Out:
#             margen  total  prorrogas
# gameId
# 0022501171      18    218          0
# 0022501172      23    257          0
# 0022501173      22    226          0
# 0022501174      26    262          0
# 0022501175      11    199          0
# 0022501176      17    207          0
# 0022501177      24    230          0
# 0022501178       4    268          0
# 0022501179      17    233          0
# 0022501180      19    259          0
# 0022501181      46    248          0
# 0022501182      20    234          0
# 0022501183      19    213          0
# 0022501184       6    242          0
# 0022501185      28    174          0

# %% [markdown]
# ## 5. La estrella de cada partido
# Bajamos el box score de cada partido y nos quedamos con la mejor actuación (Game Score).

# %%
import time
from nba_api.stats.endpoints import boxscoretraditionalv3

def game_score_col(jug):
    return (jug["points"]
        + 0.4*jug["fieldGoalsMade"] - 0.7*jug["fieldGoalsAttempted"]
        - 0.4*(jug["freeThrowsAttempted"] - jug["freeThrowsMade"])
        + 0.7*jug["reboundsOffensive"] + 0.3*jug["reboundsDefensive"]
        + jug["steals"] + 0.7*jug["assists"] + 0.7*jug["blocks"]
        - 0.4*jug["foulsPersonal"] - jug["turnovers"])

estrellas = {}          # gameId -> mejor game score
estrella_nombre = {}    # gameId -> nombre del mejor jugador

for gid in resumen.index:
    bx = boxscoretraditionalv3.BoxScoreTraditionalV3(game_id=gid, timeout=120)
    jug = bx.get_data_frames()[0]
    jug["gs"] = game_score_col(jug)

    mejor = jug.loc[jug["gs"].idxmax()]          # <-- la fila del mejor jugador
    estrellas[gid] = mejor["gs"]
    estrella_nombre[gid] = f'{mejor["firstName"]} {mejor["familyName"]}'  # <-- su nombre

    print(f'{gid}: {estrella_nombre[gid]} ({round(estrellas[gid],1)})')
    time.sleep(2)

print("\nListo, procesados", len(estrellas), "partidos")
# Out:
# 0022501171: LaMelo Ball (21.6)
# 0022501172: Bilal Coulibaly (24.3)
# 0022501173: CJ McCollum (25.4)
# 0022501174: Derik Queen (25.6)
# 0022501175: Tyrese Maxey (23.3)
# 0022501176: Jalen Brunson (22.1)
# 0022501177: Jamal Cain (19.5)
# 0022501178: Amen Thompson (40.4)
# 0022501179: AJ Green (33.5)
# 0022501180: Victor Wembanyama (38.1)
# 0022501181: Bez Mbeng (32.3)
# 0022501182: Jonas Valančiūnas (25.1)
# 0022501183: Deni Avdija (27.9)
# 0022501184: Devin Carter (24.6)
# 0022501185: LeBron James (31.4)
#
# Listo, procesados 15 partidos

# %% [markdown]
# ## 6. Calcular el KPI
# Combinamos las cuatro notas con sus pesos para el KPI (0–100) de cada partido.

# %%
# --- Añadir enfrentamiento (equipos) y nombre de la estrella al resumen ---
line = dfs[2]
enfrentamientos = line.groupby("gameId")["teamTricode"].apply(lambda x: " vs ".join(x))
resumen["partido"]  = resumen.index.map(enfrentamientos)
resumen["estrella"] = resumen.index.map(estrellas)
resumen["quien"]    = resumen.index.map(estrella_nombre)

# --- Las cuatro notas y el KPI ---
resumen["nota_igualdad"] = resumen["margen"].apply(closeness_score)
resumen["nota_ritmo"]    = resumen["total"].apply(pace_score)
resumen["nota_ot"]       = resumen["prorrogas"].apply(overtime_score)
resumen["nota_estrella"] = resumen["estrella"].apply(star_score)

W = WEIGHTS
resumen["KPI"] = round(100 * (
      W["closeness"]*resumen["nota_igualdad"]
    + W["overtime"] *resumen["nota_ot"]
    + W["pace"]     *resumen["nota_ritmo"]
    + W["star"]     *resumen["nota_estrella"]
), 1)

# %% [markdown]
# ## 7. Ranking final
# Ordenamos por KPI. La primera tabla es la limpia (presentar); la segunda muestra el desglose de notas (analizar).

# %%
# --- Ranking final, presentable ---
if len(resumen) == 0:
    print("No hubo partidos el", fecha)
else:
    ranking = resumen.sort_values("KPI", ascending=False).reset_index(drop=True)
    ranking.index = ranking.index + 1

    tabla = ranking[["partido", "quien", "estrella", "margen", "total", "prorrogas", "KPI"]].rename(columns={
        "partido":   "Partido",
        "quien":     "Estrella",
        "estrella":  "Game Score",
        "margen":    "Margen",
        "total":     "Puntos",
        "prorrogas": "Prórrogas",
    })

    mejor = tabla.iloc[0]
    print(f"Partido de la noche: {mejor['Partido']}  ·  {mejor['Estrella']} ({mejor['Game Score']})  ·  KPI {mejor['KPI']}")
    print("-" * 70)
    print(tabla.to_string())
# Out:
# Partido de la noche: HOU vs MIN  ·  Amen Thompson (40.4)  ·  KPI 66.4
# ----------------------------------------------------------------------
#        Partido           Estrella  Game Score  Margen  Puntos  Prórrogas   KPI
# 1   HOU vs MIN      Amen Thompson        40.4       4     268          0  66.4
# 2   SAC vs GSW       Devin Carter        24.6       6     242          0  44.6
# 3   SAS vs DAL  Victor Wembanyama        38.1      19     259          0  30.3
# 4   IND vs PHI       Tyrese Maxey        23.3      11     199          0  28.6
# 5   MIL vs BKN           AJ Green        33.5      17     233          0  28.0
# 6   UTA vs MEM          Bez Mbeng        32.3      46     248          0  21.3
# 7   LAL vs PHX       LeBron James        31.4      28     174          0  16.4
# 8   POR vs LAC        Deni Avdija        27.9      19     213          0  16.2
# 9   BOS vs NOP        Derik Queen        25.6      26     262          0  15.6
# 10  NYK vs TOR      Jalen Brunson        22.1      17     207          0  14.4
# 11  WAS vs MIA    Bilal Coulibaly        24.3      23     257          0  14.0
# 12  DEN vs OKC  Jonas Valančiūnas        25.1      20     234          0  12.9
# 13  CHA vs DET        LaMelo Ball        21.6      18     218          0  12.6
# 14  ATL vs CLE        CJ McCollum        25.4      22     226          0  12.6
# 15  CHI vs ORL         Jamal Cain        19.5      24     230          0   7.0

# %%
# --- Ranking final con desglose de notas ---
if len(resumen) == 0:
    print("No hubo partidos el", fecha)
else:
    ranking = resumen.sort_values("KPI", ascending=False).reset_index(drop=True)
    ranking.index = ranking.index + 1

    tabla = ranking[[
        "partido", "quien",
        "margen", "nota_igualdad",
        "total", "nota_ritmo",
        "prorrogas", "nota_ot",
        "estrella", "nota_estrella",
        "KPI"
    ]].rename(columns={
        "partido":       "Partido",
        "quien":         "Estrella",
        "margen":        "Margen",
        "nota_igualdad": "N.Igualdad",
        "total":         "Puntos",
        "nota_ritmo":    "N.Ritmo",
        "prorrogas":     "Prórrogas",
        "nota_ot":       "N.OT",
        "estrella":      "GameScore",
        "nota_estrella": "N.Estrella",
    }).round(2)

    mejor = tabla.iloc[0]
    print(f"Partido de la noche: {mejor['Partido']}  ·  {mejor['Estrella']} (GS {mejor['GameScore']})  ·  KPI {mejor['KPI']}")
    print("-" * 100)
    print(tabla.to_string())
# Out:
# Partido de la noche: HOU vs MIN  ·  Amen Thompson (GS 40.4)  ·  KPI 66.4
# ----------------------------------------------------------------------------------------------------
#        Partido           Estrella  Margen  N.Igualdad  Puntos  N.Ritmo  Prórrogas  N.OT  GameScore  N.Estrella   KPI
# 1   HOU vs MIN      Amen Thompson       4        0.80     268     1.00          0   0.0       40.4        0.85  66.4
# 2   SAC vs GSW       Devin Carter       6        0.70     242     0.70          0   0.0       24.6        0.32  44.6
# 3   SAS vs DAL  Victor Wembanyama      19        0.05     259     0.98          0   0.0       38.1        0.77  30.3
# 4   IND vs PHI       Tyrese Maxey      11        0.45     199     0.00          0   0.0       23.3        0.28  28.6
# 5   MIL vs BKN           AJ Green      17        0.15     233     0.55          0   0.0       33.5        0.62  28.0
# 6   UTA vs MEM          Bez Mbeng      46        0.00     248     0.80          0   0.0       32.3        0.58  21.3
# 7   LAL vs PHX       LeBron James      28        0.00     174     0.00          0   0.0       31.4        0.55  16.4
# 8   POR vs LAC        Deni Avdija      19        0.05     213     0.22          0   0.0       27.9        0.43  16.2
# 9   BOS vs NOP        Derik Queen      26        0.00     262     1.00          0   0.0       25.6        0.35  15.6
# 10  NYK vs TOR      Jalen Brunson      17        0.15     207     0.12          0   0.0       22.1        0.24  14.4
# 11  WAS vs MIA    Bilal Coulibaly      23        0.00     257     0.95          0   0.0       24.3        0.31  14.0
# 12  DEN vs OKC  Jonas Valančiūnas      20        0.00     234     0.57          0   0.0       25.1        0.34  12.9
# 13  CHA vs DET        LaMelo Ball      18        0.10     218     0.30          0   0.0       21.6        0.22  12.6
# 14  ATL vs CLE        CJ McCollum      22        0.00     226     0.43          0   0.0       25.4        0.35  12.6
# 15  CHI vs ORL         Jamal Cain      24        0.00     230     0.50          0   0.0       19.5        0.15   7.0
